# %%
# plt.hist(data, bins = "number_of_bins", color = "color_name", edgecolor = "color_name")

import matplotlib.pyplot as plt

marks = [56, 76, 45, 87, 89, 99, 90, 54, 66, 78, 77, 98, 100, 34, 88]

plt.hist(marks, bins = 5, color="purple", edgecolor = "grey", label = "Range of Marks", density=True)

plt.title("Marks Distribution of Students")
plt.xlabel("Marks range")
plt.ylabel("Number of Students")
plt.legend()
plt.show()
